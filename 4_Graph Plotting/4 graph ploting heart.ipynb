# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.plotting.register_matplotlib_converters()
# %matplotlib inline

# %%
df =pd.read_csv('../Desktop/DS/Heart_Disease_Prediction.csv')
df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %%
sns.lineplot(data = df)
# Out:
# <Axes: >

# %%
plt.hist(df['Thallium'])
# Out:
# (array([152.,   0.,   0.,   0.,   0.,   0.,   0.,  14.,   0., 104.]),
#  array([3. , 3.4, 3.8, 4.2, 4.6, 5. , 5.4, 5.8, 6.2, 6.6, 7. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.barplot(x=df['Cholesterol'], y=df['Thallium'])
# Out:
# <Axes: xlabel='Cholesterol', ylabel='Thallium'>

# %%
sns.scatterplot(x=df['Thallium'], y=df['Heart Disease'])
# Out:
# <Axes: xlabel='Thallium', ylabel='Heart Disease'>
