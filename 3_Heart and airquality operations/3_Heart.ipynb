# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn

# %%
df = pd.read_csv('../Desktop/DS/Heart_Disease_Prediction.csv')
df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
#      Max HR  Exercise angina  ST depression  Slope of ST  \
# 0       109                0            2.4            2
# 1       160                0            1.6            2
# 2       141                0            0.3            1
# 3       105                1            0.2            2
# 4       121                1            0.2            1
# ..      ...              ...            ...          ...
# 265     162                0            0.5            1
# 266     173                0            0.0            1
# 267     153                0            1.3            2
# 268     148                0            0.4            2
# 269     108                1            1.5            2
#
#      Number of vessels fluro  Thallium Heart Disease
# 0                          3         3      Presence
# 1                          0         7       Absence
# 2                          0         7      Presence
# 3                          1         7       Absence
# 4                          1         3       Absence
# ..                       ...       ...           ...
# 265                        0         7       Absence
# 266                        0         7       Absence
# 267                        0         3       Absence
# 268                        0         6       Absence
# 269                        3         3      Presence
#
# [270 rows x 14 columns]

# %%
#data Cleaning------------------------->
df.rename(columns={'BP' : 'BP_'},inplace=True)
df
# Out:
#      Age  Sex  Chest pain type  BP_  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
#      Max HR  Exercise angina  ST depression  Slope of ST  \
# 0       109                0            2.4            2
# 1       160                0            1.6            2
# 2       141                0            0.3            1
# 3       105                1            0.2            2
# 4       121                1            0.2            1
# ..      ...              ...            ...          ...
# 265     162                0            0.5            1
# 266     173                0            0.0            1
# 267     153                0            1.3            2
# 268     148                0            0.4            2
# 269     108                1            1.5            2
#
#      Number of vessels fluro  Thallium Heart Disease
# 0                          3         3      Presence
# 1                          0         7       Absence
# 2                          0         7      Presence
# 3                          1         7       Absence
# 4                          1         3       Absence
# ..                       ...       ...           ...
# 265                        0         7       Absence
# 266                        0         7       Absence
# 267                        0         3       Absence
# 268                        0         6       Absence
# 269                        3         3      Presence
#
# [270 rows x 14 columns]

# %%
# Adding New Cloumns (Data Transformation)
df['new_Column'] = pd.NaT
df
# Out:
#      Age  Sex  Chest pain type  BP_  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
#      Max HR  Exercise angina  ST depression  Slope of ST  \
# 0       109                0            2.4            2
# 1       160                0            1.6            2
# 2       141                0            0.3            1
# 3       105                1            0.2            2
# 4       121                1            0.2            1
# ..      ...              ...            ...          ...
# 265     162                0            0.5            1
# 266     173                0            0.0            1
# 267     153                0            1.3            2
# 268     148                0            0.4            2
# 269     108                1            1.5            2
#
#      Number of vessels fluro  Thallium Heart Disease new_Column
# 0                          3         3      Presence        NaT
# 1                          0         7       Absence        NaT
# 2                          0         7      Presence        NaT
# 3                          1         7       Absence        NaT
# 4                          1         3       Absence        NaT
# ..                       ...       ...           ...        ...
# 265                        0         7       Absence        NaT
# 266                        0         7       Absence        NaT
# 267                        0         3       Absence        NaT
# 268                        0         6       Absence        NaT
# 269                        3         3      Presence        NaT
#
# [270 rows x 15 columns]

# %%
#Replacing none values with 0(error correcting)
df.isnull().sum()
# Out:
# Age                          0
# Sex                          0
# Chest pain type              0
# BP_                          0
# Cholesterol                  0
# FBS over 120                 0
# EKG results                  0
# Max HR                       0
# Exercise angina              0
# ST depression                0
# Slope of ST                  0
# Number of vessels fluro      0
# Thallium                     0
# Heart Disease                0
# new_Column                 270
# dtype: int64

# %%
df['new_Column'] = df['new_Column'].replace(np.nan, 0)
df.isna().sum()
# Out:
# Age                        0
# Sex                        0
# Chest pain type            0
# BP_                        0
# Cholesterol                0
# FBS over 120               0
# EKG results                0
# Max HR                     0
# Exercise angina            0
# ST depression              0
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# Heart Disease              0
# new_Column                 0
# dtype: int64

# %%
#Model Building
from sklearn.linear_model import LinearRegression

# %%
X = df['Sex']
Y = df['Age']

# %%
lm=LinearRegression(fit_intercept=False)
lm.fit(df[['Sex']],df.Age)
# Out:
# LinearRegression(fit_intercept=False)

# %%
df.plot(kind='line',x='Sex',y='Age')
# Out:
# <Axes: xlabel='Sex'>

# %%
#coef_ ---> is used to display 2D Array
lm.coef_
# Out:
# array([53.84153005])

# %%
lm.predict([[8]])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([430.73224044])
